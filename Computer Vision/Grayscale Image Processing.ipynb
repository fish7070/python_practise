# %%
import numpy as np
import matplotlib.pyplot as plt

im = plt.imread(r'D:\py\python\Computer Vision\Image\albert-einstein_gray.jpg');
im2 = im.copy();
im2[23:100, 40:100] = 255;
im2[300:400, 40:100] = 0;
plt.imshow(im2, cmap = 'gray');
plt.imsave(r'D:\py\python\Computer Vision\Image\albert-einstein_gray_modfed.jpg', im2, cmap = 'gray');
