# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
grayImage = r'D:\py\python\Computer Vision\Image\albert-einstein_gray.jpg';
colourImage = r'D:\py\python\Computer Vision\Image\tulips.jpg';

I_gray = cv2.imread(grayImage, cv2.IMREAD_GRAYSCALE);
I_BGR = cv2.imread(colourImage);

plt.imshow(I_gray, cmap='gray');

# %%
I_gray_resized = cv2.resize(src=I_gray, fx=2, fy=0.5, dsize=None);
plt.imshow(I_gray_resized, cmap='gray');
plt.xticks([]);
plt.yticks([]);

# %%
I_BGR_resized = cv2.resize(src=I_BGR, fx=0.5, fy=2, dsize=None);
plt.imshow(I_BGR_resized[:,:,::-1]);

# %%
I_gray_zoomin = cv2.resize(src=I_gray, fx=2, fy=2, dsize=None);
plt.imshow(I_gray_zoomin, cmap='gray');

# %%
P = np.array([2, 4, 6]);
Sx = 2;
Sy = 2;
Sz = 4;
S = np.array([[Sx, 0, 0], [0, Sy, 0], [0, 0, Sz]]);

P_dash = S.dot(P)
P_dash
# Out:
# array([ 4,  8, 24])
