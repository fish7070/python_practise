# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
grayImage = r'D:\py\python\Computer Vision\Image\albert-einstein_gray.jpg';
colourImage = r'D:\py\python\Computer Vision\Image\tulips.jpg';

I_gray = cv2.imread(grayImage, cv2.IMREAD_GRAYSCALE);
I_BGR = cv2.imread(colourImage);
plt.imshow(I_gray, cmap='gray');

# %%
I_gray2 = np.zeros((I_gray.shape[0], I_gray.shape[1]), dtype='uint8');
for i in range(I_gray.shape[0]):
    for j in range(I_gray.shape[1]):
        I_gray2[i, I_gray.shape[1]-j-1] = I_gray[i, j];
        
plt.imshow(I_gray2, cmap='gray');
